# %%
import numpy as np
P = np.array([[1, 7], [2, 1], [3, 1]])
print(P)
# Out:
# [[1 7]
#  [2 1]
#  [3 1]]

# %%
Q = np.array([[1,2], [3,4], [5,6]])

# %%
print(P, Q)
# Out:
# [[1 7]
#  [2 1]
#  [3 1]] [[1 2]
#  [3 4]
#  [5 6]]

# %%
A1 = np.add(P,Q)
print (A1)
# Out:
# [[2 9]
#  [5 5]
#  [8 7]]

# %%
S1 = np.subtract(P,Q)

# %%
print(S1)
# Out:
# [[ 0  5]
#  [-1 -3]
#  [-2 -5]]

# %%
R = np.array([[1,2,3],[4,5,6]])

# %%
M= np.dot(P, R)

# %%
print(M)
# Out:
# [[29 37 45]
#  [ 6  9 12]
#  [ 7 11 15]]

# %%
X = np.array([[1,2],[2,3]])

# %%
Det = np.linalg.det(X)

# %%
print(Det)
# Out:
# -1.0

# %%
Inv = np.linalg.inv(X)
print(Inv)
# Out:
# [[-3.  2.]
#  [ 2. -1.]]
