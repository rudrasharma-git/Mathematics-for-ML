# %% [markdown]
# <a href="https://colab.research.google.com/github/rudrasharma-git/Mathematics-for-ML/blob/main/eigen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
A = np.array([[2,-2,3],[1,1,1],[1,3,-1]])

# %%
A
# Out:
# array([[ 2, -2,  3],
#        [ 1,  1,  1],
#        [ 1,  3, -1]])

# %%
values = np.linalg.eig(A)

# %%
values
# Out:
# EigResult(eigenvalues=array([ 3.,  1., -2.]), eigenvectors=array([[ 0.57735027,  0.57735027, -0.61684937],
#        [ 0.57735027, -0.57735027, -0.05607722],
#        [ 0.57735027, -0.57735027,  0.78508102]]))

# %%
import numpy as np
B = np.array([[2,0,0],[0,1,0],[0,0,1]])
B
# Out:
# array([[2, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]])

# %%
values2 = np.linalg.eig(B)
values2
# Out:
# EigResult(eigenvalues=array([2., 1., 1.]), eigenvectors=array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]]))
